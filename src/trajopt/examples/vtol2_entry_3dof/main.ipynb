# %% [markdown]
# ## 3DoF Entry MSL SCP
#
# Imports

# %%
# Basic imports
import importlib
import numpy as np
import matplotlib.pyplot as plt

# Trajopt imports
import trajopt; importlib.reload(trajopt)
import trajopt.core.modules.method.scp as scp
import trajopt.core.problem as prob

# %% [markdown]
# create problem and run SCP

# %%
# create problem instance
problem = prob.Problem("vtol2_entry_3dof")

# run SCP
problem = scp.run_scp(problem)

# %% [markdown]
# run SCP

# %%
problem = scp.run_scp(problem)

# %% [markdown]
# make plots

# %%
# --- 3D Interactivity (run %matplotlib widget in Jupyter) ---
#%matplotlib widget # ← run this once per notebook session

# --- Retrieve trajectory and parameters ---
zs_ref = problem.I[-1]["zs_ref"]

mission = problem.mission
model = problem.model
method = problem.method

x_init = method.zs_init[:, 0]
y_init = method.zs_init[:, 1]
z_init = method.zs_init[:, 2]

ts_init = method.ts_init
us_init = method.us_init
ts_ref  = problem.I[-1]["ts_ref"]
us_ref  = problem.I[-1]["us_ref"]

plt.plot(ts_ref * method.nondim['nt'], (zs_ref[:, 0] * method.nondim['nd'] - mission.planet['r']) / 1e3)
plt.ylabel('altitude [km]')
plt.xlabel('time [s]')

plt.figure()
plt.plot(ts_ref*method.nondim['nt'], (zs_ref[:, 3] * method.nondim['nv']))
plt.ylabel('velocity [km/s]')
plt.xlabel('time [s]')

plt.figure()
plt.plot(ts_ref*method.nondim['nt'], np.rad2deg(us_ref[:, 0]))
plt.ylabel('bank angle [deg]')
plt.xlabel('time [s]')

print(f"final time: {ts_ref[-1] * method.nondim['nt']}")
