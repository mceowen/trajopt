# %% [markdown]
# ## 3DoF Quadrotor
#
# Imports

# %%
import importlib
import numpy as np

# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt; importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer
np.random.seed(0)  # for reproducibility

# %% [markdown]
# setup problem and run SCP

# %%
# create trajectroy analyzer object
mission = "mission.yaml"
model   = "trajopt/library/models/quadrotor_3dof.yaml"
method  = "method.yaml"

trajopt = TrajectoryAnalyzer(mission, model, method)

trajopt.solve()
# Out:
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: equality_bc
#   2: state_limits: type: box
#   3: final_state: type: equality_bc
#   4: initial_control: type: equality_bc
#   5: final_control: type: equality_bc
#   6: control_rate_limit: type: control_rate_limit
#   7: max_thrust: type: max_norm_cone
#   8: min_thrust: type: nonconvex_inequality
#   9: obstacle: type: nonconvex_inequality
#
# costs:
#   0: min_time: min_time
# ------------------------------------------------------------
#
#
# nondim scales:
# ------------------------------------------------------------
# state scales: [1. 1. 1. 1. 1. 1.]
# control scales: [1. 1. 1.]
# time scale: 1.0
# ------------------------------------------------------------
#
#
# subproblem stats:
# ------------------------------------------------------------
# total number of parameters: 3031
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dz)  |      log(VB)    |   log(VB)   |  log(VB)    | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |           |  (path + NFZ)   |  (terminal) |  (dynamics) |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# ncvx_cnstr_time: 61.334848403930664
# offset keys:
# dict_keys(['path', None, 'dynamics'])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/utilities/performance_utils.py:37, in lazyprop.<locals>._lazyprop(self)
#      36 try:
# ---> 37     return getattr(self, attr_name)
#      38 except AttributeError:
#
# AttributeError: 'AddExpression' object has no attribute '_lazy_canonical_form'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/utilities/performance_utils.py:37, in lazyprop.<locals>._lazyprop(self)
#      36 try:
# ---> 37     return getattr(self, attr_name)
#      38 except AttributeError:
#
# AttributeError: 'Sum' object has no attribute '_lazy_canonical_form'
#
# During handling of the above exception, another exception occurred:
#
# AxisError                                 Traceback (most recent call last)
# Cell In[50], line 8
#       4 method  = "method.yaml"
#       6 trajopt = TrajectoryAnalyzer(mission, model, method)
# ----> 8 trajopt.solve()
#
# File ~/ACL/trajopt/src/trajopt/core/trajectory_analyzer.py:26, in TrajectoryAnalyzer.solve(self)
#      25 def solve(self):
# ---> 26     scp.run_scp(self)
#
# File ~/ACL/trajopt/src/trajopt/library/methods/scp.py:44, in run_scp(trajopt_obj)
#      41 max_iter = int(trajopt_obj.method.conv.iter_max)
#      43 for _ in range(max_iter + 1):
# ---> 44     trajopt_obj.method.subproblem.solve_iteration()  # appends a new unified record for this iteration
#      46     latest = trajopt_obj.method.subproblem.iter_data[-1]
#      47     display_subprob_status(trajopt_obj.method, latest)
#
# File ~/ACL/trajopt/src/trajopt/library/methods/subproblem.py:632, in Subproblem.solve_iteration(self)
#     630 solver_name = self.method.solver_opts.get("solver", "CLARABEL")
#     631 ignore_dpp  = self.method.flags.ignore_dpp
# --> 632 self.cp_subproblem.solve(
#     633         solver=solver_name, warm_start=False, ignore_dpp=ignore_dpp
#     634     )  # ignore_dpp=True if desired
#     635 print(self.cp_subproblem.status)
#     637 # Create unified record for this iteration and append
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/problems/problem.py:649, in Problem.solve(self, *args, **kwargs)
#     646         raise ValueError(
#     647             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     648     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 649 return solve_func(self, *args, **kwargs)
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/problems/problem.py:1215, in Problem._solve(self, solver, warm_start, verbose, bibtex, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1212         self.unpack(chain.retrieve(soln))
#    1213         return self.value
# -> 1215 data, solving_chain, inverse_data = self.get_problem_data(
#    1216     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1217 )
#    1219 if verbose:
#    1220     print(_NUM_SOLVER_STR)
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/problems/problem.py:839, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     836     s.LOGGER.info(
#     837              'Compiling problem (target solver=%s).', solver_name)
#     838     s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 839 data, inverse_data = solving_chain.apply(self, verbose)
#     840 safe_to_cache = (
#     841     isinstance(data, dict)
#     842     and s.PARAM_PROB in data
#     843     and not any(isinstance(reduction, EvalParams)
#     844                 for reduction in solving_chain.reductions)
#     845 )
#     846 self._compilation_time = time.time() - start
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/reductions/chain.py:76, in Chain.apply(self, problem, verbose)
#      74     if verbose:
#      75         s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76     problem, inv = r.apply(problem)
#      77     inverse_data.append(inv)
#      78 return problem, inverse_data
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/reductions/dcp2cone/cone_matrix_stuffing.py:411, in ConeMatrixStuffing.apply(self, problem)
#     409 # Batch expressions together, then split apart.
#     410 expr_list = [arg for c in ordered_cons for arg in c.args]
# --> 411 params_to_problem_data = extractor.affine(expr_list)
#     413 inverse_data.minimize = type(problem.objective) == Minimize
#     414 variables = problem.variables()
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/utilities/coeff_extractor.py:71, in CoeffExtractor.affine(self, expr)
#      69 assert all([e.is_dpp() for e in expr_list])
#      70 num_rows = sum([e.size for e in expr_list])
# ---> 71 op_list = [e.canonical_form[0] for e in expr_list]
#      72 return canonInterface.get_problem_matrix(op_list,
#      73                                          self.x_length,
#      74                                          self.id_map,
#    (...)
#      77                                          num_rows,
#      78                                          self.canon_backend)
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/utilities/coeff_extractor.py:71, in <listcomp>(.0)
#      69 assert all([e.is_dpp() for e in expr_list])
#      70 num_rows = sum([e.size for e in expr_list])
# ---> 71 op_list = [e.canonical_form[0] for e in expr_list]
#      72 return canonInterface.get_problem_matrix(op_list,
#      73                                          self.x_length,
#      74                                          self.id_map,
#    (...)
#      77                                          num_rows,
#      78                                          self.canon_backend)
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/utilities/performance_utils.py:39, in lazyprop.<locals>._lazyprop(self)
#      37     return getattr(self, attr_name)
#      38 except AttributeError:
# ---> 39     setattr(self, attr_name, func(self))
#      40 return getattr(self, attr_name)
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/utilities/canonical.py:54, in Canonical.canonical_form(self)
#      47 @pu.lazyprop
#      48 def canonical_form(self):
#      49     """The graph implementation of the object stored as a property.
#      50
#      51     Returns:
#      52         A tuple of (affine expression, [constraints]).
#      53     """
# ---> 54     return self.canonicalize()
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/atoms/atom.py:348, in Atom.canonicalize(self)
#     346 constraints = []
#     347 for arg in self.args:
# --> 348     obj, constr = arg.canonical_form
#     349     arg_objs.append(obj)
#     350     constraints += constr
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/utilities/performance_utils.py:39, in lazyprop.<locals>._lazyprop(self)
#      37     return getattr(self, attr_name)
#      38 except AttributeError:
# ---> 39     setattr(self, attr_name, func(self))
#      40 return getattr(self, attr_name)
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/utilities/canonical.py:54, in Canonical.canonical_form(self)
#      47 @pu.lazyprop
#      48 def canonical_form(self):
#      49     """The graph implementation of the object stored as a property.
#      50
#      51     Returns:
#      52         A tuple of (affine expression, [constraints]).
#      53     """
# ---> 54     return self.canonicalize()
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/atoms/atom.py:343, in Atom.canonicalize(self)
#     340 # Constant atoms are treated as a leaf.
#     341 if self.is_constant() and not self.parameters():
#     342     # Non-parameterized expressions are evaluated immediately.
# --> 343     return Constant(self.value).canonical_form
#     344 else:
#     345     arg_objs = []
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/atoms/atom.py:383, in Atom.value(self)
#     381 if any([p.value is None for p in self.parameters()]):
#     382     return None
# --> 383 return self._value_impl()
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/atoms/atom.py:402, in Atom._value_impl(self)
#     400         else:
#     401             arg_values.append(arg_val)
# --> 402     result = self.numeric(arg_values)
#     403 return result
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/cvxpy/atoms/affine/sum.py:100, in Sum.numeric(self, values)
#      98         result = result.flatten()
#      99 else:
# --> 100     result = np.sum(values[0], axis=self.axis, keepdims=self.keepdims)
#     101 return result
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File ~/virtualenvs/py3.11/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
data = trajopt.analyze(analysis_type="standalone", animate=True)
