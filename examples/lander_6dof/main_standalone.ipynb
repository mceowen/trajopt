# %% [markdown]
# # Lander 6-DoF
#
# Imports

# %%
import importlib
import numpy as np

# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt; importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer
np.random.seed(0)  # for reproducibility

# %% [markdown]
# setup problem and run SCP

# %%
# create trajectroy analyzer object

mission = "trajopt/library/missions/lander_scitech26.yaml"
model = "trajopt/library/models/lander_6dof.yaml"
method = "method.yaml"

trajopt = TrajectoryAnalyzer(mission, model, method)

# run SCP
trajopt.solve()
# Out:
# constraints:
#   0: dynamics: dynamics
#   1: initial_state: equality_bc
#   2: final_state: equality_bc
#   3: gimbal_limit: axis_angle_cone
#   4: max_thrust: max_norm_cone
#   5: min_thrust_norm: nonconvex_inequality
# costs:
#   0: min_time: min_time
# scales:
# d: 1.0000, t: 1.0000, m: 1.0000, v: 1.0000, a: 1.0000, f: 1.0000, fdot: 1.0000, mom: 1.0000, momdot: 1.0000, ang: 57.2958, angv: 57.2958, none: 1.0000
# constraints nondimmed!
# constraints convexified!
# costs nondimmed!
# costs convexified!
# Cost initial: 0.0
# total number of parameters: 15397
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dz)  |      log(VB)    |   log(VB)   |  log(VB)    | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |           |  (path + NFZ)   |  (terminal) |  (dynamics) |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# /Users/carlosm/Documents/guidance/hypersonics/trajopt/src/trajopt/library/methods/scp.py:851: UserWarning: The problem has an expression with dimension greater than 2. Defaulting to the SCIPY backend for canonicalization.
#   self.subproblem.solve(solver=solver_name, warm_start=True, ignore_dpp=ignore_dpp)  # ignore_dpp=True if desired
#      01     |    01704.1   |   0012.1  |   0673.9   |   -3.1    |      -12.0      |    -12.0    |     -00.3   |    optimal    |   4.50   |   0.0
#      02     |    00017.8   |   0047.4  |   0546.4   |   +0.5    |      -12.0      |    -12.0    |     -00.1   |    optimal    |   4.06   |   0.0
#      03     |    00021.6   |   0015.7  |   0662.5   |   +0.4    |      -12.0      |    -12.0    |     +00.2   |    optimal    |   4.26   |   0.0
#      04     |    00017.8   |   0018.0  |   0688.0   |   +0.2    |      -12.0      |    -12.0    |     -01.0   |    optimal    |   4.36   |   0.0
#      05     |    00034.0   |   0018.6  |   1381.3   |   -0.4    |      -12.0      |    -12.0    |     -03.2   |    optimal    |   4.64   |   0.0
#      06     |    00019.6   |   0021.7  |   0596.8   |   -1.3    |      -12.0      |    -12.0    |     -02.6   |    optimal    |   4.73   |   0.0
#      07     |    00021.1   |   0016.2  |   0771.5   |   -2.5    |      -12.0      |    -12.0    |     -04.7   |    optimal    |   4.73   |   0.0
#      08     |    00026.4   |   0016.1  |   0948.0   |   -3.3    |      -12.0      |    -12.0    |     -06.1   |    optimal    |   4.72   |   0.0
# Terminated from convergence criteria!

# %%
scenario_data = trajopt.analyze()
