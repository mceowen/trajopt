# %% [markdown]
# # 2d Car
#
# source: https://github.com/UW-ACL/SCPToolbox.jl/tree/master/test/examples/starship_flip

# %%
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer

# %%
# create trajectroy analyzer object
mission = "mission.yaml"
model   = "model.yaml"
method  = "method.yaml"

traj = TrajectoryAnalyzer(mission, model, method)

traj.solve()
# Out:
# nondim scales:
# ------------------------------------------------------------
# state scales: [1. 1. 1.]
# control scales: [1. 1.]
# time scale: 1
# ------------------------------------------------------------
#
#
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: initial_state
#   2: final_state: type: final_state
#   3: control_limits: type: control_limits
#   4: obstacle: type: nonconvex_inequality
#
# costs:
#   0: u_squared: u_squared
# ------------------------------------------------------------
#
#
#   [parameters]
#     + dynamics
#     + nonconvex_inequality
#   [variables]
#     dx: (40, 3), du: (40, 2)
#     dz: (40, 4), dnu: (40, 3)
#     free_final_time: False
#     W_stack keys: ['dynamics', 'initial_state', 'final_state', 'nonconvex_inequality']
#     dual_stack keys: ['dynamics', 'initial_state', 'final_state', 'nonconvex_inequality']
#     vb_stack keys: ['dynamics', 'initial_state', 'final_state', 'nonconvex_inequality']
#   [constraints]
#     + dynamics
#     + initial_state
#     + final_state
#     + control_limits
#     + nonconvex_inequality
#   [costs]
#     + running
#   [method costs]
#     + trust_region
#     + quadratic_penalty
#     + dual
# subproblem stats:
# ------------------------------------------------------------
# total number of cvxpy parameters: 5404
# total number of cvxpy constraints: 201
# is DPP: True
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Discretization |   Solve   |    Parse   |  log(dx/eps) | log(vb_ineq/eps) | log(vb_term/eps) | log(vb_dyn/eps) | Solve status | alpha |  Time of    |   Cost
#             |    time [ms]    | time [ms] |  time [ms] |     (state)  |    (ncvx_ineq)   |      (terminal)  |    (dynamics)   |              |       |  Flight [s] |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      1      |     1446.1      |    3.0    |   200.6    |     +1.2     |       +0.7       |       +2.4       |      +0.6       |   optimal    | 1.000 |    4.00     |    0.0
#      2      |       8.9       |    4.1    |    0.6     |     +0.6     |       +1.3       |       +0.4       |      +0.4       |   optimal    | 0.200 |    4.00     |    3.6
#      3      |       8.4       |    4.4    |    0.5     |     +2.7     |       +0.8       |       +1.3       |      +2.2       |   optimal    | 0.200 |    4.00     |   192.0
#      4      |       8.3       |    3.5    |    0.5     |     +2.1     |       +2.5       |       -1.3       |      -0.1       |   optimal    | 0.200 |    4.00     |   74.0
#      5      |       7.9       |    3.4    |    0.4     |     +1.9     |       -1.0       |       -1.9       |      -0.4       |   optimal    | 1.000 |    4.00     |   97.3
#      6      |       7.7       |    3.4    |    0.5     |     +1.7     |       -4.0       |       -1.8       |      -0.4       |   optimal    | 1.000 |    4.00     |   65.1
#      7      |       8.0       |    3.6    |    0.5     |     +1.3     |       -1.1       |       -2.4       |      -0.7       |   optimal    | 1.000 |    4.00     |   52.5
#      8      |       8.2       |    3.5    |    0.5     |     +0.9     |       -2.2       |       -2.3       |      -1.1       |   optimal    | 1.000 |    4.00     |   47.7
#      9      |       8.0       |    3.4    |    0.5     |     +0.5     |       -2.0       |       -2.4       |      -0.8       |   optimal    | 1.000 |    4.00     |   46.8
#      10     |       7.7       |    3.4    |    0.4     |     +0.4     |       -1.6       |       -2.5       |      -1.8       |   optimal    | 1.000 |    4.00     |   46.6
#      11     |       8.2       |    3.7    |    0.4     |     +0.3     |       -3.0       |       -2.8       |      -2.1       |   optimal    | 1.000 |    4.00     |   46.4
#      12     |       8.3       |    3.6    |    0.5     |     +0.2     |       -5.1       |       -2.9       |      -1.4       |   optimal    | 1.000 |    4.00     |   46.3
#      13     |       8.5       |    3.6    |    0.4     |     +0.1     |       -5.1       |       -2.9       |      -1.4       |   optimal    | 1.000 |    4.00     |   46.3
#      14     |       8.4       |    3.7    |    0.5     |     +0.0     |       -5.1       |       -2.9       |      -1.7       |   optimal    | 1.000 |    4.00     |   46.3
#      15     |       8.1       |    3.7    |    0.5     |     +0.2     |       -5.0       |       -3.0       |      -2.1       |   optimal    | 1.000 |    4.00     |   46.2
#      16     |       7.9       |    3.7    |    0.4     |     +0.0     |       -3.8       |       -3.0       |      -1.4       |   optimal    | 1.000 |    4.00     |   46.2
#      17     |       8.0       |    3.6    |    0.4     |     -0.3     |       -3.7       |       -3.0       |      -1.7       |   optimal    | 1.000 |    4.00     |   46.2
# Terminated from convergence criteria!

# %%
data = traj.analyze(analysis_type="standalone", compute_iters=True)

# %%
traj.plot(data, show_iters=False)
# Out:
# Saved 1 figures to plots/standalone/
