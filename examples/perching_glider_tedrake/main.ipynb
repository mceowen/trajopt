# %% [markdown]
# # Perching Glider
#
# source: https://underactuated.mit.edu/trajopt.html#perching

# %%
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer

# %%
# create trajectroy analyzer object
mission = "mission.yaml"
model   = "model.yaml"
method  = "method.yaml"

traj = TrajectoryAnalyzer(mission, model, method)

traj.solve()
# Out:
# nondim scales:
# ------------------------------------------------------------
# state scales: [1. 1. 1. 1. 1. 1. 1.]
# control scales: [1.]
# time scale: 1
# ------------------------------------------------------------
#
#
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: initial_state
#   2: final_state: type: final_state
#   3: state_limits: type: state_limits
#   4: terminal_box: type: nonconvex_inequality
#
# costs:
#   0: u_squared: u_squared
# ------------------------------------------------------------
#
#
#   [parameters]
#     + dynamics
#     + nonconvex_inequality
#     + free_final_time
#   [variables]
#     dx: (20, 7), du: (20, 1)
#     dz: (20, 8), dnu: (20, 2)
#     free_final_time: True
#     W_stack keys: ['dynamics', 'initial_state', 'final_state', 'nonconvex_inequality']
#     dual_stack keys: ['dynamics', 'initial_state', 'final_state', 'nonconvex_inequality']
#     vb_stack keys: ['initial_state', 'dynamics', 'final_state', 'nonconvex_inequality']
#   [constraints]
#     + dynamics
#     + initial_state
#     + final_state
#     + state_limits
#     + nonconvex_inequality
#     + free_final_time
#   [costs]
#     + running
#   [method costs]
#     + trust_region
#     + quadratic_penalty
#     + dual
# subproblem stats:
# ------------------------------------------------------------
# total number of cvxpy parameters: 6287
# total number of cvxpy constraints: 178
# is DPP: True
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Discretization |   Solve   |    Parse   |  log(dx/eps) | log(vb_ineq/eps) | log(vb_term/eps) | log(vb_dyn/eps) | Solve status | alpha |  Time of    |   Cost
#             |    time [ms]    | time [ms] |  time [ms] |     (state)  |    (ncvx_ineq)   |      (terminal)  |    (dynamics)   |              |       |  Flight [s] |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      1      |     2908.4      |    5.3    |   148.0    |     +3.2     |       +3.9       |       +3.0       |      +2.1       |   optimal    | 0.500 |    0.72     |    0.7
#      2      |       3.7       |    7.0    |    0.6     |     +3.3     |       +0.8       |       +1.0       |      +3.3       |   optimal    | 0.200 |    0.73     |   326.3
#      3      |       3.2       |    8.8    |    0.5     |     +3.7     |       +0.7       |       +0.3       |      +2.2       |   optimal    | 0.200 |    0.74     |  7381.3
#      4      |       2.9       |    5.5    |    0.5     |     +3.2     |       -1.2       |       -0.7       |      +0.8       |   optimal    | 0.500 |    0.75     |  7146.9
#      5      |       2.8       |    5.6    |    0.5     |     +2.9     |       -1.9       |       +0.3       |      +1.8       |   optimal    | 1.000 |    0.86     |  7301.2
#      6      |       2.8       |    5.5    |    0.5     |     +3.0     |       -2.4       |       -0.7       |      +1.8       |   optimal    | 1.000 |    0.93     |  6745.7
#      7      |       2.9       |    6.1    |    0.4     |     +2.7     |       -0.4       |       -0.4       |      +0.8       |   optimal    | 1.000 |    0.98     |  2055.2
#      8      |       2.7       |    5.9    |    0.6     |     +2.3     |       -4.8       |       -0.4       |      -0.9       |   optimal    | 1.000 |    0.96     |   772.9
#      9      |       3.0       |    5.4    |    0.4     |     +2.4     |       -3.8       |       -0.9       |      -0.1       |   optimal    | 1.000 |    0.97     |   219.1
#      10     |       2.8       |    5.9    |    0.5     |     +2.3     |       -5.4       |       -2.1       |      +0.6       |   optimal    | 1.000 |    0.97     |   114.9
#      11     |       3.0       |    5.8    |    0.4     |     +1.8     |       -5.6       |       -1.3       |      -0.5       |   optimal    | 1.000 |    0.95     |   96.7
#      12     |       2.7       |    6.6    |    0.5     |     +1.4     |       -6.5       |       -2.1       |      -0.9       |   optimal    | 1.000 |    0.95     |   94.1
#      13     |       2.8       |    6.7    |    0.5     |     +1.0     |       -7.3       |       -3.0       |      -1.2       |   optimal    | 1.000 |    0.95     |   93.6
#      14     |       2.9       |    6.6    |    0.5     |     +0.7     |       -7.3       |       -3.4       |      -1.8       |   optimal    | 1.000 |    0.94     |   93.5
#      15     |       2.8       |    6.8    |    0.4     |     +0.4     |       -7.3       |       -3.6       |      -1.9       |   optimal    | 1.000 |    0.94     |   93.5
#      16     |       3.0       |    7.4    |    0.5     |     +0.1     |       -7.3       |       -4.0       |      -2.1       |   optimal    | 1.000 |    0.94     |   93.5
#      17     |       3.1       |    7.7    |    0.5     |     -0.2     |       -7.3       |       -4.3       |      -1.7       |   optimal    | 1.000 |    0.94     |   93.5
# Terminated from convergence criteria!

# %%
data = traj.analyze(analysis_type="standalone", compute_iters=True)

# %%
traj.plot(data, show_iters=True)
# Out:
# Saved 1 figures to plots/standalone/
