# %% [markdown]
# # RLV Entry 3-DoF
#
# Imports

# %%
import importlib
import numpy as np

import trajopt; importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer

# %% [markdown]
# Setup problem and solve NLP

# %%
mission = "mission.yaml"
model   = "trajopt/models/rlv_entry_3dof.yaml"
method  = "method.yaml"

trajopt = TrajectoryAnalyzer(mission, model, method)

trajopt.solve()

# %%
data = trajopt.analyze()

# %%
trajopt.plot(data)
