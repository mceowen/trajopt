# %% [markdown]
# ## 3DoF Entry MSL

# %%
import importlib
import numpy as np

# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt; importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer
np.random.seed(0)  # for reproducibility

# %%
# create trajectory analyzer object
mission     = "mission.yaml"
model       = "trajopt/library/models/reentry_3dof.yaml"
method      = "method.yaml"
variations  = "variations.yaml"

trajopt     = TrajectoryAnalyzer(mission, model, method, variations=variations)

trajopt.solve()
# Out:
# phases:
#   entry: nodes [0..69], params: {'p': 0}
#   descent: nodes [70..79], params: {'p': 1}
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: equality_bc
#   2: final_state: type: equality_bc
#   3: state_limits: type: box
#   4: bank_aoa_angle_limits: type: box
#   5: chute_deploy: type: nonconvex_inequality
#
# costs:
#   0: min_lonlat_error: min_lonlat_error
# ------------------------------------------------------------
#
#
# nondim scales:
# ------------------------------------------------------------
# state scales: [1.e+06 1.e+00 1.e+00 1.e+03 1.e+00 1.e+00]
# control scales: [1. 1.]
# time scale: 1.0
# ------------------------------------------------------------
#
#
# (7,), [1 2]
# subproblem stats:
# ------------------------------------------------------------
# total number of parameters: 10877
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dx/eps) | log(vb_ineq/eps) | log(vb_term/eps) | log(vb_dyn/eps) | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |     (state)  |    (ncvx_ineq)   |      (terminal)  |    (dynamics)   |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      1      |    836.8     |   19.8    |   756.5    |     +2.4     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.98    |    0.1
#      2      |     3.3      |   19.6    |    0.5     |     +1.7     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.97    |    0.1
#      3      |     3.0      |   19.9    |    0.5     |     -0.1     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.96    |    0.1
#      4      |     3.0      |   19.7    |    0.6     |     -0.5     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.95    |    0.1
#      5      |     3.0      |   18.4    |    0.5     |     +0.1     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.92    |    0.1
#      6      |     2.9      |   21.8    |    0.5     |     +0.8     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.85    |    0.1
#      7      |     2.9      |   20.7    |    0.5     |     +1.4     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.64    |    0.2
#      8      |     2.9      |   22.5    |    0.6     |     +2.0     |       +2.3       |       +1.8       |      -inf       |   optimal    |   198.97    |    0.2
#      9      |     3.2      |   20.1    |    0.6     |     +2.7     |       +2.3       |       +1.7       |      -inf       |   optimal    |   197.71    |    0.4
#      10     |     2.9      |   21.5    |    0.5     |     +3.1     |       +1.6       |       +1.4       |      -inf       |   optimal    |   196.37    |    1.5
#      11     |     3.1      |   22.6    |    0.5     |     +3.5     |       +0.8       |       +0.8       |      -inf       |   optimal    |   196.73    |    1.6
#      12     |     2.9      |   21.1    |    0.6     |     +3.8     |       +0.7       |       +0.8       |      -inf       |   optimal    |   196.99    |    1.6
#      13     |     3.0      |   20.6    |    0.5     |     +2.7     |       +1.4       |       +0.4       |      -inf       |   optimal    |   197.47    |    1.7
#      14     |     3.7      |   21.2    |    0.5     |     +2.1     |       +1.4       |       +0.2       |      -inf       |   optimal    |   197.75    |    1.7
#      15     |     3.8      |   19.2    |    0.5     |     +1.6     |       +1.4       |       +0.3       |      -inf       |   optimal    |   198.19    |    1.7
#      16     |     3.8      |   19.4    |    0.6     |     +2.0     |       +1.4       |       +0.3       |      -inf       |   optimal    |   199.52    |    1.7
#      17     |     3.7      |   18.9    |    0.5     |     +2.5     |       +1.4       |       +0.3       |      -inf       |   optimal    |   200.99    |    1.7
#      18     |     3.6      |   20.7    |    0.5     |     +2.6     |       +1.3       |       +0.3       |      -inf       |   optimal    |   202.80    |    1.7
#      19     |     3.6      |   23.3    |    0.5     |     +3.0     |       +1.3       |       +0.2       |      -inf       |   optimal    |   205.58    |    1.8
#      20     |     3.8      |   24.5    |    0.5     |     +3.3     |       +0.9       |       -0.1       |      -inf       |   optimal    |   209.98    |    1.7
#      21     |     3.7      |   26.3    |    0.5     |     +3.6     |       +0.2       |       -0.7       |      -inf       |   optimal    |   213.42    |    1.0
#      22     |     3.7      |   25.1    |    0.5     |     +3.1     |       -4.2       |       -2.0       |      -inf       |   optimal    |   214.68    |    0.4
#      23     |     3.9      |   19.9    |    0.6     |     +2.2     |       -5.9       |       -1.3       |      -inf       |   optimal    |   214.14    |    0.7
#      24     |     3.7      |   19.3    |    0.5     |     +1.4     |       -8.9       |       -3.7       |      -inf       |   optimal    |   214.44    |    0.6
#      25     |     3.7      |   19.8    |    0.5     |     -0.7     |       -8.5       |       -4.8       |      -inf       |   optimal    |   214.46    |    0.6
# Terminated from convergence criteria!

# %%
data = trajopt.analyze(analysis_type="standalone", compute_iters=True)

# %%
trajopt.plot(data, show_iters=True)
# Out:
# Saved 10 figures to plots/standalone/
