# %% [markdown]
# ## 3DoF Entry MSL
#
# Imports

# %%
import importlib
import numpy as np

# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt; importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer
np.random.seed(0)  # for reproducibility

# %% [markdown]
# setup problem and run SCP

# %%
# create trajectroy analyzer object
mission    = "mission.yaml"
model      = "trajopt/library/models/reentry_3dof.yaml"
method     = "method.yaml"
variations = "variations.yaml"

trajopt = TrajectoryAnalyzer(mission, model, method, variations=variations)

trajopt.solve()
# Out:
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: equality_bc
#   2: final_state: type: equality_bc
#   3: state_limits: type: box
#   4: bank_aoa_angle_limits: type: box
#
# costs:
#   0: min_terminal_velocity: min_terminal_velocity
# ------------------------------------------------------------
#
#
# nondim scales:
# ------------------------------------------------------------
# state scales: [1.e+03 1.e-02 1.e-02 1.e+02 1.e+00 1.e+00]
# control scales: [1. 1.]
# time scale: 100
# ------------------------------------------------------------
#
#
# subproblem stats:
# ------------------------------------------------------------
# total number of parameters: 3424
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dz)  |      log(VB)    |   log(VB)   |  log(VB)    | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |           |  (path + NFZ)   |  (terminal) |  (dynamics) |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# offset keys:
# dict_keys(['dynamics', None])
# optimal
#      01     |    00825.5   |   0007.4  |   0119.6   |   +0.9    |      -12.0      |    +02.2    |     -12.0   |    optimal    |   293.34   |   7.2
# optimal
#      02     |    00006.3   |   0010.8  |   0000.6   |   +2.0    |      -12.0      |    +01.8    |     -12.0   |    optimal    |   273.34   |   6.8
# optimal
#      03     |    00006.2   |   0007.5  |   0000.6   |   +2.0    |      -12.0      |    +01.6    |     -12.0   |    optimal    |   258.50   |   4.9
# optimal
#      04     |    00006.0   |   0016.1  |   0000.6   |   +2.4    |      -12.0      |    +02.3    |     -12.0   |    optimal    |   239.53   |   3.4
# optimal
#      05     |    00006.0   |   0013.1  |   0000.5   |   +2.3    |      -12.0      |    +01.4    |     -12.0   |    optimal    |   222.15   |   3.3
# optimal
#      06     |    00006.9   |   0010.3  |   0000.5   |   +1.9    |      -12.0      |    +01.8    |     -12.0   |    optimal    |   205.47   |   3.2
# optimal
#      07     |    00006.2   |   0010.4  |   0000.5   |   +2.0    |      -12.0      |    +01.8    |     -12.0   |    optimal    |   201.83   |   3.3
# optimal
#      08     |    00006.3   |   0005.3  |   0000.5   |   +1.7    |      -12.0      |    +02.0    |     -12.0   |    optimal    |   201.57   |   4.7
# optimal
#      09     |    00006.4   |   0006.8  |   0000.6   |   +2.0    |      -12.0      |    +00.9    |     -12.0   |    optimal    |   208.75   |   7.4
# optimal
#      10     |    00006.4   |   0005.7  |   0000.6   |   +1.5    |      -12.0      |    +00.4    |     -12.0   |    optimal    |   212.39   |   4.8
# optimal
#      11     |    00006.1   |   0005.5  |   0000.6   |   +1.1    |      -12.0      |    -01.5    |     -12.0   |    optimal    |   223.25   |   5.0
# optimal
#      12     |    00005.9   |   0004.9  |   0000.5   |   +0.9    |      -12.0      |    -01.8    |     -12.0   |    optimal    |   231.40   |   4.8
# optimal
#      13     |    00006.0   |   0004.4  |   0000.6   |   +0.6    |      -12.0      |    -01.5    |     -12.0   |    optimal    |   234.03   |   4.8
# optimal
#      14     |    00006.0   |   0004.5  |   0000.7   |   -1.3    |      -12.0      |    -02.3    |     -12.0   |    optimal    |   234.14   |   4.8
# optimal
#      15     |    00006.1   |   0005.0  |   0000.6   |   -1.9    |      -12.0      |    -04.2    |     -12.0   |    optimal    |   234.15   |   4.8
# Terminated from convergence criteria!

# %%
data = trajopt.analyze(analysis_type="standalone", animate=True)
