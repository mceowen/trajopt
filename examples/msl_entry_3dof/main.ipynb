# %% [markdown]
# ## 3DoF Entry MSL

# %%
import importlib
import numpy as np

# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt; importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer
np.random.seed(0)  # for reproducibility

# %%
# create trajectory analyzer object
mission     = "mission.yaml"
model       = "trajopt/library/models/reentry_3dof.yaml"
method      = "method.yaml"
variations  = "variations.yaml"

trajopt     = TrajectoryAnalyzer(mission, model, method, variations=variations)

trajopt.solve()
# Out:
# phases:
#   entry: nodes [0..69], params: {'p': 0}
#   descent: nodes [70..79], params: {'p': 1}
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: equality_bc
#   2: final_state: type: equality_bc
#   3: state_limits: type: box
#   4: bank_aoa_angle_limits: type: box
#   5: chute_deploy: type: nonconvex_inequality
#
# costs:
#   0: min_lonlat_error: min_lonlat_error
# ------------------------------------------------------------
#
#
# nondim scales:
# ------------------------------------------------------------
# state scales: [1.e+06 1.e+00 1.e+00 1.e+03 1.e+00 1.e+00]
# control scales: [1. 1.]
# time scale: 1.0
# ------------------------------------------------------------
#
#
# (7,), [1 2]
# subproblem stats:
# ------------------------------------------------------------
# total number of parameters: 10877
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dx/eps) | log(vb_ineq/eps) | log(vb_term/eps) | log(vb_dyn/eps) | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |     (state)  |    (ncvx_ineq)   |      (terminal)  |    (dynamics)   |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      1      |    807.5     |   19.9    |   748.1    |     +2.4     |       +2.3       |       +1.7       |      -inf       |   optimal    |   199.98    |    0.1
#      2      |     3.2      |   19.6    |    0.6     |     +1.7     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.97    |    0.1
#      3      |     2.9      |   19.5    |    0.5     |     -0.1     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.96    |    0.1
#      4      |     2.9      |   19.9    |    0.5     |     -0.5     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.95    |    0.1
#      5      |     3.0      |   18.6    |    0.5     |     +0.1     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.92    |    0.1
#      6      |     2.9      |   22.1    |    0.5     |     +0.8     |       +2.3       |       +1.8       |      -inf       |   optimal    |   199.85    |    0.1
#      7      |     2.9      |   21.2    |    0.5     |     +1.4     |       +2.3       |       +1.7       |      -inf       |   optimal    |   199.64    |    0.2
#      8      |     2.9      |   19.6    |    0.5     |     +2.0     |       +2.3       |       +1.7       |      -inf       |   optimal    |   198.97    |    0.2
#      9      |     3.0      |   20.1    |    0.6     |     +2.7     |       +2.3       |       +1.7       |      -inf       |   optimal    |   197.71    |    0.4
#      10     |     3.0      |   21.8    |    0.6     |     +3.0     |       +1.8       |       +1.4       |      -inf       |   optimal    |   196.30    |    1.3
#      11     |     2.9      |   21.9    |    0.5     |     +3.2     |       -5.3       |       +1.0       |      -inf       |   optimal    |   196.44    |    1.4
#      12     |     2.9      |   21.7    |    0.7     |     +2.7     |       -5.0       |       +0.9       |      -inf       |   optimal    |   196.89    |    1.5
#      13     |     2.9      |   21.6    |    0.5     |     +2.9     |       +1.0       |       +0.1       |      -inf       |   optimal    |   197.50    |    1.6
#      14     |     3.0      |   20.2    |    0.6     |     +2.4     |       +1.3       |       -0.3       |      -inf       |   optimal    |   197.66    |    1.6
#      15     |     3.0      |   21.1    |    0.5     |     +1.1     |       +1.2       |       -0.4       |      -inf       |   optimal    |   197.66    |    1.6
#      16     |     3.2      |   19.8    |    0.6     |     +1.7     |       +1.2       |       -2.1       |      -inf       |   optimal    |   197.64    |    1.6
#      17     |     2.9      |   19.3    |    0.6     |     +0.1     |       +1.2       |       -2.5       |      -inf       |   optimal    |   197.65    |    1.6
#      18     |     2.9      |   19.6    |    0.5     |     -0.2     |       +1.2       |       -4.4       |      -inf       |   optimal    |   197.66    |    1.6
#      19     |     2.9      |   19.0    |    0.5     |     -0.4     |       +1.2       |       -3.7       |      -inf       |   optimal    |   197.68    |    1.6
#      20     |     2.9      |   19.1    |    0.6     |     -0.3     |       +1.2       |       -2.3       |      -inf       |   optimal    |   197.69    |    1.6
#      21     |     2.9      |   19.9    |    0.5     |     -0.4     |       +1.2       |       -2.1       |      -inf       |   optimal    |   197.71    |    1.6
#      22     |     3.0      |   19.2    |    0.5     |     -0.2     |       +1.2       |       -2.2       |      -inf       |   optimal    |   197.73    |    1.6
#      23     |     3.2      |   18.6    |    0.5     |     +0.1     |       +1.2       |       -2.2       |      -inf       |   optimal    |   197.76    |    1.6
#      24     |     3.0      |   19.2    |    0.6     |     +0.6     |       +1.2       |       -2.2       |      -inf       |   optimal    |   197.83    |    1.6
#      25     |     2.9      |   21.1    |    0.5     |     +1.1     |       +1.2       |       -2.2       |      -inf       |   optimal    |   198.03    |    1.6
#      26     |     3.0      |   17.6    |    0.6     |     +1.7     |       +1.2       |       -2.2       |      -inf       |   optimal    |   198.64    |    1.6
#      27     |     2.9      |   17.6    |    0.5     |     +2.0     |       +1.2       |       -2.1       |      -inf       |   optimal    |   199.96    |    1.6
#      28     |     2.9      |   18.8    |    0.6     |     +2.2     |       +1.2       |       -2.1       |      -inf       |   optimal    |   201.26    |    1.6
#      29     |     3.6      |   19.5    |    0.6     |     +2.7     |       +1.1       |       -2.1       |      -inf       |   optimal    |   202.65    |    1.6
#      30     |     4.0      |   20.0    |    0.6     |     +3.2     |       +1.0       |       -2.3       |      -inf       |   optimal    |   204.39    |    1.6
#      31     |     3.7      |   20.6    |    0.5     |     +3.2     |       -4.5       |       -2.8       |      -inf       |   optimal    |   206.37    |    1.4
#      32     |     3.6      |   18.3    |    0.4     |     +2.7     |       -5.1       |       -3.3       |      -inf       |   optimal    |   206.31    |    1.3
#      33     |     3.7      |   18.5    |    0.5     |     +0.4     |       -6.6       |       -5.8       |      -inf       |   optimal    |   206.31    |    1.3
#      34     |     3.7      |   20.2    |    0.5     |     -0.2     |       -5.7       |       -6.1       |      -inf       |   optimal    |   206.32    |    1.3
# Terminated from convergence criteria!

# %%
data = trajopt.analyze(analysis_type="standalone", compute_iters=True)

# %%
trajopt.plot(data, show_iters=True)
# Out:
# Saved 10 figures to plots/standalone/
