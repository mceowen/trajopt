# %% [markdown]
# ## 3DoF Entry VTOL w/o Aoa SCP
#
# Imports

# %%
import importlib
import numpy as np

# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt; importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer
np.random.seed(0)  # for reproducibility

# %% [markdown]
# setup problem and run SCP

# %%
# create trajectroy analyzer object
trajopt = TrajectoryAnalyzer("trajopt.yaml")

# run SCP
trajopt.solve()
# Out:
# constraints:
#   0: dynamics: dynamics
#   1: initial_state: equality_bc
#   2: final_state: equality_bc
#   3: state_limits: box
#   4: bank_aoa_angle_limits: box
# costs:
#   0: min_terminal_velocity: terminal_state
# scales:
# d: 3396190.0000, t: 956.3609, m: 2900.0000, v: 3551.1593, a: 3.7132, f: 10768.2800, fdot: 11.2596, mom: 36571124853.2001, momdot: 38239878.1734, ang: 57.2958, angv: 0.0599, none: 1.0000
# constraints nondimmed!
# constraints convexified!
# costs nondimmed!
# costs convexified!
# Initial guess time: 0.2888591249939054 seconds
# initial nondim state:
# [ 1.0371004   0.          0.          1.64594135 -0.27000244  0.        ]
# Cost initial: 0.0
# total number of parameters: 9538
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dz)  |      log(VB)    |   log(VB)   |  log(VB)    | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |           |  (path + NFZ)   |  (terminal) |  (dynamics) |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:41: UserWarning: The problem has an expression with dimension greater than 2. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
#      01     |    00823.5   |   0009.8  |   2910.8   |   -4.5    |      -12.0      |    -02.2    |     -12.0   |    optimal    |   200.32   |   0.0
#      02     |    00011.7   |   0009.1  |   0000.8   |   -4.5    |      -12.0      |    -02.2    |     -12.0   |    optimal    |   200.64   |   0.0
#      03     |    00010.0   |   0009.6  |   0000.8   |   -4.4    |      -12.0      |    -02.2    |     -12.0   |    optimal    |   201.00   |   0.0
#      04     |    00010.1   |   0006.3  |   0000.8   |   -2.6    |      -12.0      |    -02.2    |     -12.0   |    optimal    |   214.25   |   0.0
#      05     |    00010.4   |   0013.4  |   0000.7   |   -2.2    |      -12.0      |    -03.5    |     -12.0   |    optimal    |   196.07   |   0.0
#      06     |    00010.3   |   0011.4  |   0000.7   |   -3.0    |      -12.0      |    -03.5    |     -12.0   |    optimal    |   199.61   |   0.0
#      07     |    00011.0   |   0013.5  |   0001.1   |   -3.6    |      -12.0      |    -03.5    |     -12.0   |    optimal    |   201.86   |   0.0
#      08     |    00010.7   |   0016.7  |   0000.8   |   -2.7    |      -12.0      |    -03.6    |     -12.0   |    optimal    |   221.74   |   0.0
#      09     |    00010.9   |   0014.3  |   0001.0   |   -2.7    |      -12.0      |    -03.7    |     -12.0   |    optimal    |   241.74   |   0.0
#      10     |    00010.5   |   0010.6  |   0000.7   |   -3.0    |      -12.0      |    -04.0    |     -12.0   |    optimal    |   248.92   |   0.0
#      11     |    00010.0   |   0010.5  |   0000.8   |   -2.8    |      -12.0      |    -04.0    |     -12.0   |    optimal    |   263.52   |   0.0
#      12     |    00009.7   |   0010.2  |   0000.7   |   -3.3    |      -12.0      |    -04.4    |     -12.0   |    optimal    |   262.51   |   0.0
#      13     |    00010.1   |   0010.8  |   0001.0   |   -3.3    |      -12.0      |    -04.4    |     -12.0   |    optimal    |   256.86   |   0.0
#      14     |    00009.8   |   0007.1  |   0001.0   |   -3.6    |      -12.0      |    -04.6    |     -12.0   |    optimal    |   255.92   |   0.0
# Terminated from convergence criteria!

# %%
scenario_data = trajopt.analyze()
# Out:
# constraint_name: state_limits
# constraint_name: bank_aoa_angle_limits
