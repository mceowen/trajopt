# %% [markdown]
# ## 3DoF Entry VTOL w/o Aoa SCP
#
# Imports

# %%
import importlib
# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt
importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer

# %% [markdown]
# setup problem and run SCP

# %%
# create trajectroy analyzer object
mission = "mission.yaml"
model   = "trajopt/models/reentry_3dof.yaml"
method  = "method.yaml"
trajopt = TrajectoryAnalyzer(mission, model, method)

# run SCP
trajopt.solve()
# Out:
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: equality_bc
#   2: final_state: type: equality_bc
#   3: state_limits: type: box
#   4: bank_angle_limit: type: box
#   5: max_Q: type: nonconvex_inequality
#   6: max_q: type: nonconvex_inequality
#   7: max_load: type: nonconvex_inequality
#
# costs:
#   0: min_terminal_velocity: min_terminal_velocity
#   1: control_rate_regularization: control_rate_regularization
# ------------------------------------------------------------
# Warning: no scale provided for control group 'aoa', defaulting to 1.0.
#
#
# nondim scales:
# ------------------------------------------------------------
# state scales: [1.e+06 1.e+00 1.e+00 1.e+03 1.e+00 1.e+00]
# control scales: [1. 1.]
# time scale: 1.0
# ------------------------------------------------------------
#
#
# subproblem stats:
# ------------------------------------------------------------
# total number of parameters: 7914
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dx/eps) | log(vb_ineq/eps) | log(vb_term/eps) | log(vb_dyn/eps) | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |     (state)  |    (ncvx_ineq)   |      (terminal)  |    (dynamics)   |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      1      |    829.8     |   88.7    |   224.6    |     +1.8     |       +3.9       |       +3.8       |      -inf       |   optimal    |   1700.00   |    0.9
#      2      |     3.5      |   105.3   |    0.8     |     +1.1     |       +2.6       |       +3.4       |      -inf       |   optimal    |   1700.00   |    0.7
#      3      |     3.2      |   106.4   |    0.6     |     +0.9     |       +2.7       |       +2.9       |      -inf       |   optimal    |   1700.00   |    0.7
#      4      |     3.4      |   122.8   |    0.7     |     +0.7     |       +0.3       |       +2.5       |      -inf       |   optimal    |   1700.00   |    0.6
#      5      |     3.2      |   124.4   |    0.7     |     -0.0     |       +1.1       |       +1.9       |      -inf       |   optimal    |   1700.00   |    0.7
#      6      |     3.4      |   123.1   |    0.7     |     -0.5     |       +1.3       |       +1.1       |      -inf       |   optimal    |   1700.00   |    0.7
#      7      |     3.2      |   123.8   |    0.7     |     -2.0     |       +1.2       |       +1.1       |      -inf       |   optimal    |   1700.00   |    0.7
#      8      |     3.4      |   132.2   |    0.6     |     -1.8     |       +0.4       |       +1.1       |      -inf       |   optimal    |   1700.00   |    0.7
#      9      |     3.1      |   133.0   |    0.6     |     -1.5     |       +0.3       |       +1.1       |      -inf       |   optimal    |   1700.00   |    0.7
#      10     |     3.4      |   131.1   |    0.6     |     -1.0     |       +0.0       |       +1.1       |      -inf       |   optimal    |   1700.00   |    0.7
#      11     |     3.1      |   123.8   |    0.6     |     -0.5     |       +0.2       |       +1.1       |      -inf       |   optimal    |   1700.00   |    0.7
#      12     |     3.3      |   114.5   |    0.7     |     +0.0     |       +0.2       |       +1.1       |      -inf       |   optimal    |   1700.00   |    0.7
#      13     |     3.1      |   105.3   |    0.6     |     +0.6     |       +0.2       |       +1.0       |      -inf       |   optimal    |   1700.00   |    0.7
#      14     |     3.3      |   106.3   |    0.7     |     +0.9     |       +3.3       |       +0.7       |      -inf       |   optimal    |   1700.00   |    0.7
#      15     |     3.2      |   122.6   |    0.6     |     +1.1     |       +3.1       |       -0.4       |      -inf       |   optimal    |   1700.00   |    0.7
#      16     |     3.3      |   132.8   |    0.6     |     +0.7     |       +2.4       |       -1.1       |      -inf       |   optimal    |   1700.00   |    0.7
#      17     |     3.2      |   149.4   |    0.6     |     +0.2     |       +1.3       |       -1.0       |      -inf       |   optimal    |   1700.00   |    0.7
#      18     |     3.2      |   370.8   |    0.7     |     -0.8     |       -2.0       |       -1.4       |      -inf       |   optimal    |   1700.00   |    0.7
# Terminated from convergence criteria!

# %% [markdown]
# mc analysis

# %%
data = trajopt.analyze(analysis_type="standalone", compute_iters=True)

# %%
trajopt.plot(data, show_iters=True)
# Out:
# Saved 9 figures to plots/standalone/
