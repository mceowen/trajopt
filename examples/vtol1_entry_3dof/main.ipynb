# %% [markdown]
# ## 3DoF Entry VTOL w/o Aoa SCP
#
# Imports

# %%
import importlib
import numpy as np
# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt
importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer

# %% [markdown]
# setup problem and run SCP

# %%
# create trajectroy analyzer object
mission = "mission.yaml"
model   = "trajopt/library/models/reentry_3dof.yaml"
method  = "method.yaml"
trajopt = TrajectoryAnalyzer(mission, model, method)

# run SCP
trajopt.solve()
# Out:
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: equality_bc
#   2: final_state: type: equality_bc
#   3: state_limits: type: box
#   4: bank_angle_limit: type: box
#   5: bank_angle_rate_limit: type: control_rate_limit
#   6: max_Q: type: nonconvex_inequality
#   7: max_q: type: nonconvex_inequality
#   8: max_load: type: nonconvex_inequality
#
# costs:
#   0: min_terminal_velocity: min_terminal_velocity
# ------------------------------------------------------------
# Warning: no scale provided for control group 'aoa', defaulting to 1.0.
#
#
# nondim scales:
# ------------------------------------------------------------
# state scales: [1000.   10.   10.  700.   10.   10.]
# control scales: [1. 1.]
# time scale: 100
# ------------------------------------------------------------
#
#
# subproblem stats:
# ------------------------------------------------------------
# total number of parameters: 4748
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dz)  |      log(VB)    |   log(VB)   |  log(VB)    | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |           |  (path + NFZ)   |  (terminal) |  (dynamics) |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# offset keys:
# dict_keys(['dynamics', 'path', None])
# optimal
#      01     |    00704.7   |   0007.4  |   0212.0   |   +0.2    |      -12.0      |    +01.1    |     -12.0   |    optimal    |   1717.59   |   1.2
# optimal
#      02     |    00006.7   |   0012.7  |   0000.6   |   +0.9    |      -12.0      |    +00.8    |     -12.0   |    optimal    |   1767.59   |   0.8
# optimal
#      03     |    00006.5   |   0007.6  |   0000.6   |   +1.1    |      -12.0      |    +00.7    |     -12.0   |    optimal    |   1768.87   |   0.4
# optimal
#      04     |    00006.3   |   0007.6  |   0000.7   |   +1.0    |      -12.0      |    -00.0    |     -12.0   |    optimal    |   1749.44   |   0.6
# optimal
#      05     |    00006.5   |   0008.1  |   0000.8   |   +1.0    |      -12.0      |    -00.5    |     -12.0   |    optimal    |   1723.74   |   0.7
# optimal
#      06     |    00006.1   |   0008.1  |   0000.6   |   +0.4    |      -12.0      |    -01.0    |     -12.0   |    optimal    |   1719.05   |   0.7
# optimal
#      07     |    00006.1   |   0007.8  |   0000.7   |   +0.1    |      -12.0      |    -00.5    |     -12.0   |    optimal    |   1717.11   |   0.7
# optimal
#      08     |    00006.2   |   0008.5  |   0000.6   |   -0.1    |      -12.0      |    -00.4    |     -12.0   |    optimal    |   1724.23   |   0.7
# optimal
#      09     |    00006.1   |   0008.8  |   0000.5   |   +0.1    |      -12.0      |    -00.8    |     -12.0   |    optimal    |   1735.03   |   0.7
# optimal
#      10     |    00006.3   |   0007.9  |   0000.6   |   +0.0    |      -12.0      |    -01.3    |     -12.0   |    optimal    |   1736.84   |   0.7
# optimal
#      11     |    00006.2   |   0007.3  |   0000.5   |   -0.2    |      -12.0      |    -01.2    |     -12.0   |    optimal    |   1734.17   |   0.7
# optimal
#      12     |    00006.2   |   0007.2  |   0000.5   |   -0.6    |      -12.0      |    -01.1    |     -12.0   |    optimal    |   1731.68   |   0.7
# optimal
#      13     |    00006.0   |   0007.4  |   0000.7   |   -0.3    |      -12.0      |    -01.4    |     -12.0   |    optimal    |   1730.74   |   0.7
# optimal
#      14     |    00006.2   |   0007.4  |   0000.5   |   -0.3    |      -12.0      |    -02.9    |     -12.0   |    optimal    |   1729.55   |   0.7
# optimal
#      15     |    00006.1   |   0008.2  |   0000.5   |   -0.6    |      -12.0      |    -01.7    |     -12.0   |    optimal    |   1728.57   |   0.7
# optimal
#      16     |    00006.2   |   0007.5  |   0000.5   |   -1.1    |      -12.0      |    -01.8    |     -12.0   |    optimal    |   1727.98   |   0.7
# optimal
#      17     |    00006.2   |   0007.5  |   0000.6   |   -0.8    |      -12.0      |    -02.3    |     -12.0   |    optimal    |   1728.46   |   0.7
# optimal
#      18     |    00006.1   |   0007.4  |   0000.6   |   -0.8    |      -12.0      |    -02.4    |     -12.0   |    optimal    |   1728.98   |   0.7
# optimal
#      19     |    00006.1   |   0007.0  |   0000.5   |   -1.5    |      -12.0      |    -02.6    |     -12.0   |    optimal    |   1729.28   |   0.7
# optimal
#      20     |    00006.2   |   0007.0  |   0000.7   |   -1.7    |      -12.0      |    -03.0    |     -12.0   |    optimal    |   1729.13   |   0.7
# optimal
#      21     |    00006.1   |   0006.9  |   0000.5   |   -1.7    |      -12.0      |    -04.1    |     -12.0   |    optimal    |   1728.99   |   0.7
# optimal
#      22     |    00005.9   |   0006.7  |   0000.5   |   -2.6    |      -12.0      |    -03.5    |     -12.0   |    optimal    |   1728.96   |   0.7
# optimal
#      23     |    00006.1   |   0006.8  |   0000.6   |   -2.5    |      -12.0      |    -04.0    |     -12.0   |    optimal    |   1728.99   |   0.7
# optimal
#      24     |    00006.3   |   0007.1  |   0000.6   |   -2.8    |      -12.0      |    -04.7    |     -12.0   |    optimal    |   1729.01   |   0.7
# optimal
#      25     |    00006.4   |   0007.4  |   0000.6   |   -2.9    |      -12.0      |    -04.6    |     -12.0   |    optimal    |   1729.02   |   0.7
# optimal
#      26     |    00006.7   |   0006.9  |   0000.6   |   -2.9    |      -12.0      |    -05.2    |     -12.0   |    optimal    |   1729.02   |   0.7
# Terminated from convergence criteria!

# %% [markdown]
# mc analysis

# %%
results = trajopt.analyze(animate=True)
