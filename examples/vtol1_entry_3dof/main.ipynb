# %% [markdown]
# ## 3DoF Entry VTOL w/o Aoa SCP
#
# Imports

# %%
import importlib
import numpy as np
# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt
importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer

# %% [markdown]
# setup problem and run SCP

# %%
# create trajectroy analyzer object
mission = "mission.yaml"
model   = "trajopt/library/models/reentry_3dof.yaml"
method  = "method.yaml"
trajopt = TrajectoryAnalyzer(mission, model, method)

# run SCP
trajopt.solve()
# Out:
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: equality_bc
#   2: final_state: type: equality_bc
#   3: state_limits: type: box
#   4: bank_angle_limit: type: box
#   5: bank_angle_rate_limit: type: control_rate_limit
#   6: max_Q: type: nonconvex_inequality
#   7: max_q: type: nonconvex_inequality
#   8: max_load: type: nonconvex_inequality
#
# costs:
#   0: min_terminal_velocity: min_terminal_velocity
# ------------------------------------------------------------
# Warning: no scale provided for control group 'aoa', defaulting to 1.0.
#
#
# nondim scales:
# ------------------------------------------------------------
# state scales: [1000.   10.   10.  700.   10.   10.]
# control scales: [1. 1.]
# time scale: 100
# ------------------------------------------------------------
#
#
# subproblem stats:
# ------------------------------------------------------------
# total number of parameters: 4748
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dz)  |      log(VB)    |   log(VB)   |  log(VB)    | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |           |  (path + NFZ)   |  (terminal) |  (dynamics) |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# offset keys:
# dict_keys(['path', 'dynamics', None])
# optimal
#      01     |    00598.3   |   0005.5  |   0225.8   |   +0.2    |      -12.0      |    +01.1    |     -12.0   |    optimal    |   1717.59   |   1.2
# optimal
#      02     |    00005.4   |   0005.7  |   0000.5   |   +0.6    |      -12.0      |    +00.9    |     -12.0   |    optimal    |   1767.59   |   1.0
# optimal
#      03     |    00005.3   |   0006.3  |   0000.4   |   +0.7    |      -12.0      |    +00.6    |     -12.0   |    optimal    |   1817.59   |   0.7
# optimal
#      04     |    00005.2   |   0007.7  |   0000.6   |   +0.6    |      -12.0      |    -00.2    |     -12.0   |    optimal    |   1836.75   |   0.6
# optimal
#      05     |    00005.3   |   0005.8  |   0000.5   |   +0.1    |      -12.0      |    -00.3    |     -12.0   |    optimal    |   1820.82   |   0.7
# optimal
#      06     |    00005.3   |   0006.3  |   0000.5   |   +0.1    |      -12.0      |    -00.4    |     -12.0   |    optimal    |   1799.97   |   0.7
# optimal
#      07     |    00005.3   |   0006.1  |   0000.5   |   +0.2    |      -12.0      |    -00.6    |     -12.0   |    optimal    |   1771.20   |   0.7
# optimal
#      08     |    00005.2   |   0005.9  |   0000.5   |   +0.4    |      -12.0      |    -00.9    |     -12.0   |    optimal    |   1723.58   |   0.7
# optimal
#      09     |    00005.3   |   0005.6  |   0000.5   |   +0.3    |      -12.0      |    -00.4    |     -12.0   |    optimal    |   1676.14   |   0.7
# optimal
#      10     |    00005.6   |   0005.5  |   0000.5   |   +0.2    |      -12.0      |    -00.3    |     -12.0   |    optimal    |   1664.07   |   0.7
# optimal
#      11     |    00005.3   |   0005.4  |   0000.7   |   -0.2    |      -12.0      |    -00.5    |     -12.0   |    optimal    |   1682.18   |   0.7
# optimal
#      12     |    00005.3   |   0006.5  |   0000.5   |   +0.1    |      -12.0      |    -00.7    |     -12.0   |    optimal    |   1703.63   |   0.7
# optimal
#      13     |    00005.2   |   0007.0  |   0000.6   |   +0.2    |      -12.0      |    -01.2    |     -12.0   |    optimal    |   1725.77   |   0.7
# optimal
#      14     |    00005.4   |   0006.5  |   0000.5   |   +0.1    |      -12.0      |    -01.4    |     -12.0   |    optimal    |   1743.69   |   0.7
# optimal
#      15     |    00005.1   |   0006.1  |   0000.5   |   -0.0    |      -12.0      |    -01.0    |     -12.0   |    optimal    |   1755.40   |   0.7
# optimal
#      16     |    00005.4   |   0005.9  |   0000.4   |   -0.3    |      -12.0      |    -00.9    |     -12.0   |    optimal    |   1760.33   |   0.7
# optimal
#      17     |    00005.1   |   0006.2  |   0000.5   |   -0.5    |      -12.0      |    -00.9    |     -12.0   |    optimal    |   1758.62   |   0.7
# optimal
#      18     |    00005.2   |   0005.9  |   0000.4   |   -0.2    |      -12.0      |    -01.1    |     -12.0   |    optimal    |   1752.44   |   0.7
# optimal
#      19     |    00005.2   |   0005.9  |   0000.5   |   -0.0    |      -12.0      |    -01.5    |     -12.0   |    optimal    |   1743.69   |   0.7
# optimal
#      20     |    00005.4   |   0006.1  |   0000.5   |   -0.1    |      -12.0      |    -01.7    |     -12.0   |    optimal    |   1735.37   |   0.7
# optimal
#      21     |    00005.2   |   0005.6  |   0000.5   |   -0.3    |      -12.0      |    -01.3    |     -12.0   |    optimal    |   1730.04   |   0.7
# optimal
#      22     |    00005.3   |   0005.6  |   0000.5   |   -0.8    |      -12.0      |    -01.2    |     -12.0   |    optimal    |   1728.84   |   0.7
# optimal
#      23     |    00005.6   |   0005.7  |   0000.5   |   -0.7    |      -12.0      |    -01.3    |     -12.0   |    optimal    |   1731.27   |   0.7
# optimal
#      24     |    00005.3   |   0005.6  |   0000.5   |   -0.5    |      -12.0      |    -01.6    |     -12.0   |    optimal    |   1735.03   |   0.7
# optimal
#      25     |    00005.2   |   0005.6  |   0000.5   |   -0.5    |      -12.0      |    -02.7    |     -12.0   |    optimal    |   1738.78   |   0.7
# optimal
#      26     |    00005.2   |   0005.6  |   0000.4   |   -0.6    |      -12.0      |    -01.8    |     -12.0   |    optimal    |   1741.59   |   0.6
# optimal
#      27     |    00006.2   |   0009.1  |   0000.6   |   -0.8    |      -12.0      |    -01.6    |     -12.0   |    optimal    |   1742.81   |   0.6
# optimal
#      28     |    00005.4   |   0006.0  |   0000.6   |   -1.0    |      -12.0      |    -01.7    |     -12.0   |    optimal    |   1741.84   |   0.7
# optimal
#      29     |    00005.2   |   0005.7  |   0000.6   |   -0.8    |      -12.0      |    -02.0    |     -12.0   |    optimal    |   1740.36   |   0.7
# optimal
#      30     |    00005.3   |   0005.8  |   0000.7   |   -0.8    |      -12.0      |    -03.2    |     -12.0   |    optimal    |   1738.90   |   0.7
# optimal
#      31     |    00005.3   |   0005.7  |   0000.6   |   -1.0    |      -12.0      |    -02.2    |     -12.0   |    optimal    |   1737.96   |   0.7
# optimal
#      32     |    00005.2   |   0005.6  |   0000.6   |   -1.6    |      -12.0      |    -02.1    |     -12.0   |    optimal    |   1737.76   |   0.7
# optimal
#      33     |    00005.2   |   0005.3  |   0000.6   |   -1.2    |      -12.0      |    -02.3    |     -12.0   |    optimal    |   1738.22   |   0.7
# optimal
#      34     |    00005.3   |   0005.7  |   0000.7   |   -1.1    |      -12.0      |    -02.9    |     -12.0   |    optimal    |   1738.79   |   0.7
# optimal
#      35     |    00005.3   |   0005.4  |   0000.5   |   -1.3    |      -12.0      |    -02.8    |     -12.0   |    optimal    |   1739.21   |   0.7
# optimal
#      36     |    00005.1   |   0005.9  |   0000.5   |   -1.7    |      -12.0      |    -02.6    |     -12.0   |    optimal    |   1739.36   |   0.7
# optimal
#      37     |    00005.1   |   0005.8  |   0000.5   |   -1.7    |      -12.0      |    -02.8    |     -12.0   |    optimal    |   1739.22   |   0.7
# optimal
#      38     |    00005.2   |   0005.8  |   0000.5   |   -1.6    |      -12.0      |    -03.4    |     -12.0   |    optimal    |   1739.04   |   0.7
# optimal
#      39     |    00005.3   |   0005.6  |   0000.5   |   -1.8    |      -12.0      |    -03.4    |     -12.0   |    optimal    |   1738.91   |   0.7
# optimal
#      40     |    00005.0   |   0005.3  |   0000.5   |   -2.5    |      -12.0      |    -03.2    |     -12.0   |    optimal    |   1738.89   |   0.7
# optimal
#      41     |    00005.1   |   0005.2  |   0000.5   |   -2.3    |      -12.0      |    -03.5    |     -12.0   |    optimal    |   1738.93   |   0.7
# optimal
#      42     |    00005.1   |   0005.4  |   0000.4   |   -2.2    |      -12.0      |    -04.5    |     -12.0   |    optimal    |   1738.97   |   0.7
# optimal
#      43     |    00005.1   |   0005.2  |   0000.4   |   -2.5    |      -12.0      |    -03.9    |     -12.0   |    optimal    |   1739.00   |   0.7
# optimal
#      44     |    00005.0   |   0005.2  |   0000.5   |   -2.6    |      -12.0      |    -03.9    |     -12.0   |    optimal    |   1739.00   |   0.7
# optimal
#      45     |    00005.0   |   0005.3  |   0000.8   |   -2.6    |      -12.0      |    -04.3    |     -12.0   |    optimal    |   1738.99   |   0.7
# optimal
#      46     |    00005.3   |   0005.4  |   0000.5   |   -2.6    |      -12.0      |    -05.3    |     -12.0   |    optimal    |   1738.98   |   0.7
# optimal
#      47     |    00005.4   |   0005.4  |   0000.7   |   -2.6    |      -12.0      |    -04.6    |     -12.0   |    optimal    |   1738.98   |   0.7
# optimal
#      48     |    00005.6   |   0005.5  |   0000.6   |   -2.6    |      -12.0      |    -04.6    |     -12.0   |    optimal    |   1738.98   |   0.7
# optimal
#      49     |    00005.9   |   0005.7  |   0000.6   |   -2.6    |      -12.0      |    -05.0    |     -12.0   |    optimal    |   1738.98   |   0.7
# optimal
#      50     |    00005.3   |   0005.2  |   0000.6   |   -2.6    |      -12.0      |    -05.5    |     -12.0   |    optimal    |   1738.98   |   0.7
# optimal
#      51     |    00005.2   |   0005.2  |   0000.5   |   -2.6    |      -12.0      |    -05.1    |     -12.0   |    optimal    |   1738.98   |   0.7
# optimal
#      52     |    00008.3   |   0005.1  |   0000.5   |   -2.6    |      -12.0      |    -05.2    |     -12.0   |    optimal    |   1738.98   |   0.7
# optimal
#      53     |    00005.2   |   0005.3  |   0000.5   |   -2.6    |      -12.0      |    -05.5    |     -12.0   |    optimal    |   1738.98   |   0.7
# optimal
#      54     |    00005.1   |   0005.4  |   0000.4   |   -2.6    |      -12.0      |    -06.0    |     -12.0   |    optimal    |   1738.98   |   0.7
# Terminated from convergence criteria!

# %% [markdown]
# mc analysis

# %%
results = trajopt.analyze(animate=True)
