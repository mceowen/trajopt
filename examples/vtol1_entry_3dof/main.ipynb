# %% [markdown]
# ## 3DoF Entry VTOL w/o Aoa SCP
#
# Imports

# %%
import importlib
# Trajopt imports --> pip install -e ~/ACL/trajopt
import trajopt
importlib.reload(trajopt)
from trajopt.core.trajectory_analyzer import TrajectoryAnalyzer

# %% [markdown]
# setup problem and run SCP

# %%
# create trajectroy analyzer object
mission = "mission.yaml"
model   = "trajopt/models/reentry_3dof.yaml"
method  = "method.yaml"
trajopt = TrajectoryAnalyzer(mission, model, method)

# run SCP
trajopt.solve()
# Out:
# problem configuration:
# ------------------------------------------------------------
# constraints:
#   0: dynamics: type: dynamics
#   1: initial_state: type: equality_bc
#   2: final_state: type: equality_bc
#   3: state_limits: type: box
#   4: bank_angle_limit: type: box
#   5: max_Q: type: nonconvex_inequality
#   6: max_q: type: nonconvex_inequality
#   7: max_load: type: nonconvex_inequality
#
# costs:
#   0: min_terminal_velocity: min_terminal_velocity
#   1: control_rate_regularization: control_rate_regularization
# ------------------------------------------------------------
# Warning: no scale provided for control group 'aoa', defaulting to 1.0.
#
#
# nondim scales:
# ------------------------------------------------------------
# state scales: [1.e+06 1.e+00 1.e+00 1.e+03 1.e+00 1.e+00]
# control scales: [1. 1.]
# time scale: 1.0
# ------------------------------------------------------------
#
#
# subproblem stats:
# ------------------------------------------------------------
# total number of parameters: 9165
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Iteration |  Propagation |   Solve   |    Parse   |  log(dx/eps) | log(vb_ineq/eps) | log(vb_term/eps) | log(vb_dyn/eps) | Solve status |  Time of    |   Cost
#             |   time [ms]  | time [ms] |  time [ms] |     (state)  |    (ncvx_ineq)   |      (terminal)  |    (dynamics)   |              |  Flight [s] |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      1      |    857.8     |    5.3    |   489.1    |     +1.8     |       +3.7       |       +3.7       |      -inf       |   optimal    |   1700.14   |    1.6
#      2      |     5.9      |    5.8    |    0.6     |     +1.1     |       +2.6       |       +3.5       |      -inf       |   optimal    |   1700.16   |    2.0
#      3      |     6.5      |    5.7    |    0.6     |     +0.7     |       +2.6       |       +3.4       |      -inf       |   optimal    |   1699.96   |    1.8
#      4      |     5.6      |    5.9    |    0.6     |     +1.0     |       +2.7       |       +2.9       |      -inf       |   optimal    |   1699.68   |    2.1
#      5      |     5.5      |    5.9    |    0.6     |     +0.9     |       +1.7       |       +3.0       |      -inf       |   optimal    |   1699.43   |    2.4
#      6      |     6.2      |    6.2    |    0.6     |     +0.1     |       +1.9       |       +2.9       |      -inf       |   optimal    |   1699.33   |    2.1
#      7      |     6.1      |    5.9    |    0.6     |     +0.4     |       +1.9       |       +2.4       |      -inf       |   optimal    |   1699.47   |    1.7
#      8      |     6.2      |    6.4    |    0.6     |     +0.1     |       +0.7       |       +1.8       |      -inf       |   optimal    |   1699.55   |    1.5
#      9      |     5.6      |    6.3    |    0.6     |     -0.8     |       +0.9       |       +1.6       |      -inf       |   optimal    |   1699.55   |    1.5
#      10     |     6.2      |    6.2    |    0.6     |     -0.6     |       +1.0       |       +1.1       |      -inf       |   optimal    |   1699.54   |    1.4
#      11     |     6.2      |    6.4    |    0.6     |     -1.1     |       +1.1       |       +1.1       |      -inf       |   optimal    |   1699.55   |    1.4
#      12     |     6.2      |    6.2    |    0.6     |     -1.2     |       +1.1       |       +1.1       |      -inf       |   optimal    |   1699.56   |    1.4
#      13     |     6.6      |    6.1    |    0.7     |     -1.2     |       +1.1       |       +1.1       |      -inf       |   optimal    |   1699.56   |    1.3
#      14     |     6.2      |    6.2    |    0.6     |     -1.2     |       +0.9       |       +1.1       |      -inf       |   optimal    |   1699.57   |    1.3
#      15     |     6.2      |    6.2    |    0.6     |     -1.3     |       +0.6       |       +1.1       |      -inf       |   optimal    |   1699.58   |    1.3
#      16     |     6.2      |    6.3    |    0.6     |     -1.3     |       +0.6       |       +1.1       |      -inf       |   optimal    |   1699.59   |    1.2
#      17     |     6.1      |    6.3    |    0.6     |     -1.3     |       +0.5       |       +1.1       |      -inf       |   optimal    |   1699.60   |    1.2
#      18     |     6.2      |    6.4    |    0.5     |     -1.3     |       +0.3       |       +1.1       |      -inf       |   optimal    |   1699.61   |    1.2
#      19     |     6.1      |    6.2    |    0.6     |     -1.4     |       +0.2       |       +1.1       |      -inf       |   optimal    |   1699.63   |    1.2
#      20     |     6.1      |    6.0    |    0.6     |     -1.4     |       +0.7       |       +1.1       |      -inf       |   optimal    |   1699.66   |    1.2
#      21     |     6.2      |    6.1    |    0.6     |     -1.1     |       +0.5       |       +1.1       |      -inf       |   optimal    |   1699.70   |    1.1
#      22     |     6.2      |    5.9    |    0.6     |     -0.9     |       +0.3       |       +1.1       |      -inf       |   optimal    |   1699.77   |    1.1
#      23     |     6.3      |    6.3    |    0.6     |     -0.6     |       +0.1       |       +1.1       |      -inf       |   optimal    |   1699.88   |    1.1
#      24     |     6.6      |    6.0    |    0.7     |     -0.3     |       -0.1       |       +1.1       |      -inf       |   optimal    |   1700.06   |    1.1
#      25     |     6.2      |    5.8    |    0.6     |     -0.1     |       +0.5       |       +1.1       |      -inf       |   optimal    |   1700.35   |    1.2
#      26     |     6.3      |    5.8    |    0.6     |     +0.2     |       +0.3       |       +1.1       |      -inf       |   optimal    |   1700.81   |    1.4
#      27     |     6.2      |    5.7    |    0.6     |     +0.5     |       +0.2       |       +1.1       |      -inf       |   optimal    |   1701.53   |    1.9
#      28     |     6.2      |    5.6    |    0.6     |     +0.8     |       +0.5       |       +1.0       |      -inf       |   optimal    |   1702.39   |    4.0
#      29     |     7.4      |    6.4    |    0.6     |     +1.1     |       +2.5       |       +0.8       |      -inf       |   optimal    |   1703.25   |   10.2
#      30     |     7.4      |    7.2    |    0.6     |     +0.6     |       +3.9       |       +0.6       |      -inf       |   optimal    |   1704.13   |   12.5
#      31     |     6.9      |    6.6    |    0.6     |     +0.8     |       +2.8       |       -0.1       |      -inf       |   optimal    |   1705.01   |   22.0
#      32     |     6.8      |    6.3    |    0.6     |     +0.7     |       +3.5       |       -0.3       |      -inf       |   optimal    |   1705.59   |   22.4
#      33     |     7.3      |    7.1    |    0.6     |     +0.4     |       -0.7       |       -1.2       |      -inf       |   optimal    |   1705.88   |   20.4
#      34     |     7.4      |    7.2    |    0.6     |     +0.1     |       -1.0       |       -1.1       |      -inf       |   optimal    |   1706.22   |   19.2
#      35     |     7.6      |    7.5    |    0.6     |     +0.1     |       -1.1       |       -1.0       |      -inf       |   optimal    |   1706.52   |   18.1
#      36     |     8.1      |    7.1    |    0.6     |     +0.1     |       -1.0       |       -0.9       |      -inf       |   optimal    |   1706.79   |   17.0
#      37     |     7.3      |    7.0    |    0.6     |     -0.0     |       -1.0       |       -0.9       |      -inf       |   optimal    |   1707.00   |   15.8
# Terminated from convergence criteria!

# %% [markdown]
# mc analysis

# %%
data = trajopt.analyze(analysis_type="standalone", compute_iters=True)

# %%
trajopt.plot(data, show_iters=True)
# Out:
# Saved 18 figures to plots/standalone/
